# %%
from barnum import gen_data
import random

suffices = ['Ltd', 'Holdings Ltd', 'Intl Ltd', 'Sales Ltd']
for i in range(100):
    print(gen_data.create_company_name(biz_type="technology")+" " + random.choices(suffices)[0])
# Out:
# East Hill Electronic Ltd
# Data Star Medicine Sales Ltd
# Source Consulting Electronics Holdings Ltd
# Studio Technology Network Ltd
# Consulting Atlantic Network Ltd
# Building Star Vision Ltd
# Solutions Studio General Holdings Ltd
# Direct Research Medicine Holdings Ltd
# Power Signal Research Ltd
# Innovation Digital Holdings Ltd
# Speed Network Analysis Sales Ltd
# Hardware Venture Solutions Ltd
# Internet Contract Ltd
# Digital Frontier Holdings Ltd
# Solutions Direct Vision Sales Ltd
# Advanced Contract Studio Holdings Ltd
# Hardware Construction Universal Intl Ltd
# Galaxy Omega Direct Sales Ltd
# West Innovation Analysis Sales Ltd
# Research Digital People Sales Ltd
# Universal Medicine Digital Sales Ltd
# Future Analysis Consulting Sales Ltd
# Industries Studio Star Intl Ltd
# North Internet Hardware Ltd
# Solutions Software Intl Ltd
# Bell Software Speed Sales Ltd
# Solutions People Ltd
# Solutions Systems Max Holdings Ltd
# Vision Adventure Pacific Intl Ltd
# ...
